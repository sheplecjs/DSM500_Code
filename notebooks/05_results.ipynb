# %%
import re
import pandas as pd

# %%
def get_results(file: str) -> pd.DataFrame:
    """Grabs results from text file and organizes into dataframe.

    Args:
        file (str): path to the results file.

    Returns:
        pd.DataFrame
    """

    p = []

    reg = re.compile("[0-9.]+")

    with open(file) as f:
        lines = f.readlines()

    for l, s in zip(lines[::3], lines[1::3]):
        parsed = l.split("_")
        dataset = parsed[0]
        try:
            t = int(parsed[1])
            trunc = t
            model = parsed[2] + parsed[3]
        except ValueError:
            trunc = 1
            model = parsed[1] + parsed[2]

        scores = reg.findall(s)
        mse = scores[0]
        mae = scores[1]

        p.append([dataset, trunc, model, mse, mae])

    return pd.DataFrame(p, columns=["data", "truncated", "model", "mse", "mae"])

# %%
results = get_results("result.txt")
results
# Out:
#    data  truncated              model                    mse  \
# 0   SPD          8  Transformercustom    0.01845727488398552
# 1   CHZ          1  Transformercustom   0.002477737609297037
# 2   NZD          1  Transformercustom   0.004671357572078705
# 3   JPY          4  Transformercustom    0.39662158489227295
# 4   JPY          6  Transformercustom   0.006859296467155218
# 5   RMB          8  Transformercustom    0.01689082942903042
# 6   GBP          4  Transformercustom    0.01827644743025303
# 7   AUD          1  Transformercustom   0.005069757346063852
# 8   GBP          6  Transformercustom   0.005877324845641851
# 9   AUD          8  Transformercustom   0.014381805434823036
# 10  CAD          8  Transformercustom   0.032485734671354294
# 11  CAD          1  Transformercustom   0.016543466597795486
# 12  NZD          4  Transformercustom    0.00515448022633791
# 13  NZD          6  Transformercustom   0.004335454199463129
# 14  SPD          1  Transformercustom   0.004301791545003653
# 15  CHZ          8  Transformercustom   0.003551421221345663
# 16  CAD          6  Transformercustom    0.13805797696113586
# 17  CHZ          4  Transformercustom    0.00798586755990982
# 18  RMB          1  Transformercustom  0.0023319690953940153
# 19  CAD          4  Transformercustom    0.01792694628238678
# 20  CHZ          6  Transformercustom  0.0032122505363076925
# 21  NZD          8  Transformercustom   0.008973091840744019
# 22  AUD          4  Transformercustom   0.014522002078592777
# 23  JPY          1  Transformercustom  0.0014868015423417091
# 24  AUD          6  Transformercustom   0.020162325352430344
# 25  GBP          8  Transformercustom   0.013279086910188198
# 26  GBP          1  Transformercustom   0.008031610399484634
# 27  RMB          4  Transformercustom     1.4852172136306763
# 28  RMB          6  Transformercustom  0.0004916726029478014
# 29  JPY          8  Transformercustom   0.004476477392017841
# 30  SPD          6  Transformercustom   0.006056039594113827
# 31  SPD          4  Transformercustom     0.2578113377094269
# 32  SPD          8     Transformersdm      6.131313800811768
# 33  CHZ          1     Transformersdm      3.090000867843628
# 34  NZD          1     Transformersdm     0.6585016250610352
# 35  JPY          4     Transformersdm     13.268024444580078
# 36  JPY          6     Transformersdm      4.305517196655273
# 37  RMB          8     Transformersdm    0.40206727385520935
# 38  GBP          4     Transformersdm     1.4949685335159302
# 39  AUD          1     Transformersdm     1.0892436504364014
# 40  GBP          6     Transformersdm     2.0052478313446045
# 41  AUD          8     Transformersdm     1.0270602703094482
# 42  CAD          8     Transformersdm     2.1385865211486816
# 43  CAD          1     Transformersdm      0.922381579875946
#
#                      mae
# 0     0.1148136779665947
# 1    0.04239877313375473
# 2    0.05306434631347656
# 3     0.6075755953788757
# 4    0.06801002472639084
# 5    0.12408606708049774
# 6    0.10629767179489136
# 7    0.05382591113448143
# 8    0.05762201175093651
# 9    0.08848363161087036
# 10   0.12573669850826263
# 11   0.09634269028902054
# 12   0.05864016339182854
# 13  0.050975702702999115
# 14   0.05097509175539017
# 15   0.04637405648827553
# 16   0.28674885630607605
# 17   0.07400383800268173
# 18  0.035973526537418365
# 19   0.10280225425958633
# 20   0.04614743962883949
# 21   0.07378707081079483
# 22   0.09503554552793503
# 23  0.028862223029136658
# 24   0.10908497124910355
# 25   0.08430006355047226
# 26   0.06787274777889252
# 27    1.2111051082611084
# 28  0.014651020988821983
# 29   0.05439925938844681
# 30   0.06059090048074722
# 31   0.47333893179893494
# 32     2.336796283721924
# 33     1.630499005317688
# 34    0.6855478882789612
# 35     3.522346019744873
# 36    1.9485169649124146
# 37    0.5294167399406433
# 38    1.0644365549087524
# 39    0.8920793533325195
# 40    1.2613931894302368
# 41    0.8455813527107239
# 42     1.248862862586975
# 43    0.7472629547119141

# %%
results["truncated"].value_counts()
# Out:
# 8    12
# 1    12
# 4    10
# 6    10
# Name: truncated, dtype: int64

# %%
results[results["model"] == "Transformersdm"]
# Out:
#    data  truncated           model                  mse                 mae
# 32  SPD          8  Transformersdm    6.131313800811768   2.336796283721924
# 33  CHZ          1  Transformersdm    3.090000867843628   1.630499005317688
# 34  NZD          1  Transformersdm   0.6585016250610352  0.6855478882789612
# 35  JPY          4  Transformersdm   13.268024444580078   3.522346019744873
# 36  JPY          6  Transformersdm    4.305517196655273  1.9485169649124146
# 37  RMB          8  Transformersdm  0.40206727385520935  0.5294167399406433
# 38  GBP          4  Transformersdm   1.4949685335159302  1.0644365549087524
# 39  AUD          1  Transformersdm   1.0892436504364014  0.8920793533325195
# 40  GBP          6  Transformersdm   2.0052478313446045  1.2613931894302368
# 41  AUD          8  Transformersdm   1.0270602703094482  0.8455813527107239
# 42  CAD          8  Transformersdm   2.1385865211486816   1.248862862586975
# 43  CAD          1  Transformersdm    0.922381579875946  0.7472629547119141
